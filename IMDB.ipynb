# %% [markdown]
# <a href="https://colab.research.google.com/github/ops865ops865/main-tibame20251203/blob/main/IMDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Langchain LLM

# %% [markdown]
# # 選擇模型

# %% [markdown]
# ## Gemini

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

API_KEY = "這邊請改成你自己的API_KEY值"
API_KEY = "AIzaSyDzaAESuHuY1v1LgVgjcsNJemPSzHcyuJQ"

model_name = 'gemini-2.5-flash'

llm = ChatGoogleGenerativeAI(
    model=model_name,
    google_api_key=API_KEY
)

# %% [markdown]
# ## LM Studio

# %%
from langchain_openai import ChatOpenAI
model_name = 'gemma3:12b'  # 指定模型名稱，模型名稱會根據下載的模型不同而改變
base_url = 'http://localhost:11434/v1'  # 設定 LM Studio 本地伺服器的URL
# base_url = 'http://192.168.31.200:1234/v1'

llm = ChatOpenAI(
    model=model_name,
    openai_api_key="not-needed",
    openai_api_base=base_url
)

# %% [markdown]
# ## Ollama

# %%
# %%writefile go.sh
# #!/bin/bash
# set -e  # 若有錯誤立即停止執行
#
# echo "🚀 開始安裝 Ollama..."
#
# # 安裝 Ollama
# curl -fsSL https://ollama.com/install.sh | sh
#
# # 重新載入 PATH（確保第一次執行也能找到 ollama）
# export PATH=$PATH:/usr/local/bin
#
# # 啟動 Ollama 服務（背景執行）
# echo "🟢 啟動 Ollama 服務中..."
# ollama serve &
#
# # 等待服務啟動（避免太快執行 pull）
# sleep 5
#
# # 拉取指定模型
# echo "📦 下載模型 gemma3:12b..."
# ollama pull gemma3:12b
#
# # 安裝 Python 套件
# echo "🐍 安裝 Python 模組 ollama..."
# pip install -q ollama
#
# echo ""
# echo "✅ 安裝完畢~~~~~~~"
# Out:
# Writing go.sh

# %% [markdown]
# 執行上面的程式後，打開終端機後輸入
# ```
# sh go.sh
# ```
# 需要等終端機內的程式安裝完畢後，才能繼續下面的程式

# %%
! pip install langchain_openai

# %%
from langchain_openai import ChatOpenAI
model_name = 'gemma3:12b'  # 指定模型名稱，模型名稱會根據下載的模型不同而改變
base_url = 'http://localhost:11434/v1'  # 設定 LM Studio 本地伺服器的URL

llm = ChatOpenAI(
    model=model_name,
    openai_api_key="not-needed",
    openai_api_base=base_url
)

# %% [markdown]
# ## 測試模型

# %%
from langchain_core.messages import HumanMessage
messages = [
    HumanMessage("機器學習的定義")
]
result = llm.invoke(messages)
print(result.content)
# Out:
# ## 機器學習 (Machine Learning) 的定義
#
# 機器學習是一種**人工智能 (Artificial Intelligence, AI) 的分支**，它讓計算機系統通過**數據**而非通過明確編程來學習和改進。 換句話說，機器學習的目標是構建能夠從經驗中學習並在沒有人工干預的情況下做出預測或決策的算法。
#
# **更詳細地說，機器學習包括以下核心概念：**
#
# * **數據 (Data):**  機器學習算法的“燃料”。 數據可以是各種形式，如圖像、文本、數字、聲音等。
# * **算法 (Algorithm):** 用於分析數據並從中學習的方法。 存在各種各樣的機器學習算法，每種算法都適合不同的問題類型。
# * **模型 (Model):**  通過訓練算法在數據上得到的表示。 模型可以被用來進行預測，分類問題，或其他任務。
# * **學習 (Learning):**  算法根據數據調整自身參數，以提高預測或決策的準確性的過程。
# * **經驗 (Experience):**  數據本身。
#
# **不同的視角下的定義：**
#
# * **理論定義 (Tom Mitchell):** “一個機器學習算法是一個從經驗 E 中學習一個目標函 F 的計算程序，使得在新的經驗 E' 上，F 的性能 R 得到提高。”
# * **實際操作定義:**  “使用數據來訓練一個模型，使模型能夠在沒有人工干預的情況下進行預測或決策。”
#
# **與傳統編程的區別：**
#
# | 特性 | 傳統編程 | 機器學習 |
# |---|---|---|
# | **指令** | 直接編寫指令 | 從數據學習指令 |
# | **問題解決** | 適用於已知問題，例如計算器 | 適用於解決複雜問題，例如圖像識別 |
# | **目標** | 執行明確的任務 | 根據數據調整模型以提高性能 |
# | **數據** | 數據輸入後，遵循編寫的程式進行處理 | 數據輸入後，程式根據數據進行學習 |
#
#
# **總而言之，機器學習是一種利用算法讓計算機從數據中學習，並在沒有明确编程的情况下自动化任务的方法。**
#
# **一些機器學習的例子：**
#
# * **垃圾郵件過濾器:** 學習垃圾郵件的特征，並將郵件分類為垃圾郵件或非垃圾郵件。
# ...

# %% [markdown]
# # 生成文字

# %%
from langchain_core.messages import HumanMessage, SystemMessage
def chat(system_prompt, user_prompt, stream = False):
    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(content=user_prompt),
    ]

    if stream:
        for chunk in llm.stream(messages):
            print(chunk.content, end="")
    else:
        return llm.invoke(messages).content

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lakshmi25npathi/imdb-dataset-of-50k-movie-reviews")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'imdb-dataset-of-50k-movie-reviews' dataset.
# Path to dataset files: /kaggle/input/imdb-dataset-of-50k-movie-reviews

# %%
filename = "/kaggle/input/imdb-dataset-of-50k-movie-reviews/IMDB Dataset.csv"

import pandas as pd
data = pd.read_csv(filename)
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
data['review'][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the 
# ...

# %%
system_prompt = '''
分析使用者的評論中的電影是屬於哪一種類別
輸出為類別的中文名稱
不要輸出任何評論
'''

chat(system_prompt, data['review'][1], True)
# Out:
# 劇情/傳記

# %%
data['電影類別'] = ""

# %%
for n in range(0,5):
  result = chat(system_prompt, data['review'][n])
  data.loc[n, '電影類別'] = result

# %%
system_prompt = '''
分析使用者的評論中的情緒是正面或負面
輸出為情緒的分數1~5分，(1代表極度負面, 3代表中立, 5代表極度正面)
不要輸出任何評論
'''

chat(system_prompt, data['review'][1], True)
# Out:
# 5

# %%
data['review'][1]
# Out:
# 'A wonderful little production. <br /><br />The filming technique is very unassuming- very old-time-BBC fashion and gives a comforting, and sometimes discomforting, sense of realism to the entire piece. <br /><br />The actors are extremely well chosen- Michael Sheen not only "has got all the polari" but he has all the voices down pat too! You can truly see the seamless editing guided by the references to Williams\' diary entries, not only is it well worth the watching but it is a terrificly written and performed piece. A masterful production about one of the great master\'s of comedy and his life. <br /><br />The realism really comes home with the little things: the fantasy of the guard which, rather than use the traditional \'dream\' techniques remains solid then disappears. It plays on our knowledge and our senses, particularly with the scenes concerning Orton and Halliwell and the sets (particularly of their flat with Halliwell\'s murals decorating every surface) are terribly well
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...
